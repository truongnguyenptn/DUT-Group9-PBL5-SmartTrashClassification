# %% [markdown]
# <a href="https://colab.research.google.com/github/chel310/Trash_classifier/blob/main/trash_classifier_MobileNetV2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lets clone our repository initially

# %%
# !git clone   https://github.com/chel310/Trash_classifier.git 
# %cd Trash_classifier/
# Out:
# Cloning into 'Trash_classifier'...
# remote: Enumerating objects: 28888, done.
# remote: Counting objects: 100% (128/128), done.
# remote: Compressing objects: 100% (109/109), done.
# ^Cceiving objects:   7% (2023/28888), 33.09 MiB | 2.67 MiB/s
# [Errno 2] No such file or directory: 'Trash_classifier/'
# /home/truongnguyen/Data/CODE/uni/Ky6/PBL6/DUT-Group9-PBL5-SmartTrashClassification/Trash_classifier

# %% [markdown]
# We will be using tensorflow as our default library for transfer learning. Code uasge  was based on [tensorflow tutorial](https://www.tensorflow.org/tutorials/images/transfer_learning_with_hub) for the same

# %%
# %pip install tensorflow_hub 
# %pip install tensorflow==2.13.1
# %pip install --upgrade tf-models-official
import numpy as np
import time

import PIL.Image as Image
import matplotlib.pylab as plt

import tensorflow as tf
import tensorflow_hub as hub
version_fn = getattr(tf.keras, "version", None)
if version_fn and version_fn().startswith("3."):
    import tf_keras as keras
else:
    keras = tf.keras
import tf_keras
# Out:
# Requirement already satisfied: tensorflow_hub in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (0.16.1)
# Requirement already satisfied: numpy>=1.12.0 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorflow_hub) (1.24.3)
# Requirement already satisfied: protobuf>=3.19.6 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorflow_hub) (3.20.3)
# Requirement already satisfied: tf-keras>=2.14.1 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorflow_hub) (2.16.0)
# Collecting tensorflow<2.17,>=2.16 (from tf-keras>=2.14.1->tensorflow_hub)
#   Obtaining dependency information for tensorflow<2.17,>=2.16 from https://files.pythonhosted.org/packages/58/70/e8ac764ec80810eefcbab0cb1d21dbba6cf26719c44cd6d9a5e9f0407935/tensorflow-2.16.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached tensorflow-2.16.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (24.3.7)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (3.3.0)
# Requirement already satisfied: packaging in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (23.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (2.31.0)
# Requirement already satisfied: setuptools in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (1.62.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (3.2.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (0.36.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (0.43.0)
# Requirement already satisfied: rich in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (13.7.1)
# Requirement already satisfied: namex in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (0.0.7)
# Requirement already satisfied: optree in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (0.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (0.1.2)
# Using cached tensorflow-2.16.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (589.8 MB)
# Installing collected packages: tensorflow
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.13.1
#     Uninstalling tensorflow-2.13.1:
#       Successfully uninstalled tensorflow-2.13.1
#   Rolling back uninstall of tensorflow
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/bin/import_pb_to_tensorboard
#    from /tmp/pip-uninstall-2qabbk3f/import_pb_to_tensorboard
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/bin/saved_model_cli
#    from /tmp/pip-uninstall-2qabbk3f/saved_model_cli
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/bin/tensorboard
#    from /tmp/pip-uninstall-2qabbk3f/tensorboard
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/bin/tf_upgrade_v2
#    from /tmp/pip-uninstall-2qabbk3f/tf_upgrade_v2
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/bin/tflite_convert
#    from /tmp/pip-uninstall-2qabbk3f/tflite_convert
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/bin/toco
#    from /tmp/pip-uninstall-2qabbk3f/toco
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/bin/toco_from_protos
#    from /tmp/pip-uninstall-2qabbk3f/toco_from_protos
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow-2.13.1.dist-info/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/~ensorflow-2.13.1.dist-info
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/__init__.py
#    from /tmp/pip-uninstall-rvcjcszb/__init__.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/__pycache__/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/~_pycache__
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/__init__.py
#    from /tmp/pip-uninstall-rvcjcszb/_api/__init__.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/__pycache__/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/~_pycache__
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/__init__.py
#    from /tmp/pip-uninstall-rvcjcszb/_api/v2/__init__.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/__internal__/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~_internal__
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/__operators__/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~_operators__
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/__pycache__/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~_pycache__
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/audio/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~udio
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/autodiff/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~utodiff
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/autograph/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~utograph
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/bitwise/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~itwise
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/__init__.py
#    from /tmp/pip-uninstall-rvcjcszb/_api/v2/compat/__init__.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/__pycache__/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/~_pycache__
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/__init__.py
#    from /tmp/pip-uninstall-rvcjcszb/_api/v2/compat/v1/__init__.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/__internal__/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~_internal__
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/__pycache__/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~_pycache__
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/app/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~pp
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/audio/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~udio
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/autograph/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~utograph
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/bitwise/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~itwise
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/compat/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~ompat
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/config/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~onfig
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/data/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~ata
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/debugging/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~ebugging
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/distribute/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~istribute
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/distributions/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~istributions
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/dtypes/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~types
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/errors/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~rrors
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/experimental/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~xperimental
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/feature_column/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~eature_column
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/gfile/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~file
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/graph_util/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~raph_util
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/image/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~mage
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/initializers/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~nitializers
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/io/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~o
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/layers/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~ayers
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/linalg/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~inalg
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/lite/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~ite
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/logging/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~ogging
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/lookup/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~ookup
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/losses/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~osses
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/manip/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~anip
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/math/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~ath
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/metrics/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~etrics
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/mixed_precision/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~ixed_precision
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/mlir/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~lir
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/nest/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~est
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/nn/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~n
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/profiler/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~rofiler
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/python_io/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~ython_io
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/quantization/__init__.py
#    from /tmp/pip-uninstall-rvcjcszb/_api/v2/compat/v1/quantization/__init__.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/quantization/__pycache__/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/quantization/~_pycache__
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/queue/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~ueue
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/ragged/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~agged
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/random/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~andom
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/raw_ops/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~aw_ops
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/resource_loader/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~esource_loader
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/saved_model/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~aved_model
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/sets/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~ets
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/signal/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~ignal
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/sparse/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~parse
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/spectral/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~pectral
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/strings/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~trings
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/summary/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~ummary
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/sysconfig/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~ysconfig
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/test/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~-st
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/tpu/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~pu
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/train/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~rain
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/types/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~ypes
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/user_ops/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~ser_ops
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/version/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~ersion
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/xla/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v1/~la
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/__init__.py
#    from /tmp/pip-uninstall-rvcjcszb/_api/v2/compat/v2/__init__.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/__internal__/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~_internal__
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/__operators__/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~_operators__
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/__pycache__/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~_pycache__
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/audio/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~udio
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/autodiff/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~utodiff
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/autograph/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~utograph
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/bitwise/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~itwise
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/compat/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~ompat
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/config/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~onfig
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/data/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~ata
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/debugging/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~ebugging
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/distribute/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~istribute
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/dtypes/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~types
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/errors/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~rrors
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/experimental/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~xperimental
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/feature_column/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~eature_column
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/graph_util/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~raph_util
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/image/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~mage
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/io/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~o
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/linalg/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~inalg
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/lite/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~ite
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/lookup/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~ookup
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/math/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~ath
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/mlir/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~lir
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/nest/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~est
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/nn/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~n
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/profiler/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~rofiler
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/quantization/__init__.py
#    from /tmp/pip-uninstall-rvcjcszb/_api/v2/compat/v2/quantization/__init__.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/quantization/__pycache__/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/quantization/~_pycache__
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/queue/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~ueue
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/ragged/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~agged
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/random/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~andom
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/raw_ops/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~aw_ops
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/saved_model/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~aved_model
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/sets/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~ets
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/signal/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~ignal
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/sparse/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~parse
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/strings/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~trings
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/summary/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~ummary
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/sysconfig/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~ysconfig
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/test/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~-st
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/tpu/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~pu
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/train/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~rain
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/types/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~ypes
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/version/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~ersion
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/xla/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/compat/v2/~la
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/config/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~onfig
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/data/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~ata
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/debugging/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~ebugging
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/distribute/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~istribute
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/dtypes/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~types
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/errors/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~rrors
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/experimental/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~xperimental
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/feature_column/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~eature_column
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/graph_util/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~raph_util
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/image/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~mage
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/io/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~o
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/linalg/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~inalg
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/lite/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~ite
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/lookup/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~ookup
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/math/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~ath
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/mlir/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~lir
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/nest/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~est
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/nn/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~n
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/profiler/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~rofiler
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/quantization/__init__.py
#    from /tmp/pip-uninstall-rvcjcszb/_api/v2/quantization/__init__.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/quantization/__pycache__/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/quantization/~_pycache__
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/queue/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~ueue
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/ragged/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~agged
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/random/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~andom
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/raw_ops/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~aw_ops
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/saved_model/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~aved_model
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/sets/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~ets
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/signal/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~ignal
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/sparse/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~parse
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/strings/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~trings
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/summary/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~ummary
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/sysconfig/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~ysconfig
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/test/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~-st
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/tpu/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~pu
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/train/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~rain
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/types/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~ypes
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/v2.py
#    from /tmp/pip-uninstall-rvcjcszb/_api/v2/v2.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/version/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~ersion
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/xla/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/_api/v2/~la
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/compiler/__init__.py
#    from /tmp/pip-uninstall-rvcjcszb/compiler/__init__.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/compiler/__pycache__/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/compiler/~_pycache__
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/compiler/jit/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/compiler/~it
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/compiler/mlir/__init__.py
#    from /tmp/pip-uninstall-rvcjcszb/compiler/mlir/__init__.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/compiler/mlir/__pycache__/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/compiler/mlir/~_pycache__
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/compiler/mlir/quantization/__init__.py
#    from /tmp/pip-uninstall-rvcjcszb/compiler/mlir/quantization/__init__.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/compiler/mlir/quantization/__pycache__/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/compiler/mlir/quantization/~_pycache__
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/compiler/mlir/quantization/stablehlo/__init__.py
#    from /tmp/pip-uninstall-rvcjcszb/compiler/mlir/quantization/stablehlo/__init__.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/compiler/mlir/quantization/stablehlo/__pycache__/__init__.cpython-311.pyc
#    from /tmp/pip-uninstall-rvcjcszb/compiler/mlir/quantization/stablehlo/__pycache__/__init__.cpython-311.pyc
# ...
#    from /tmp/pip-uninstall-wxyocacd/python/util/__pycache__/keras_deps.cpython-311.pyc
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/__pycache__/keyword_args.cpython-311.pyc
#    from /tmp/pip-uninstall-wxyocacd/python/util/__pycache__/keyword_args.cpython-311.pyc
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/__pycache__/lazy_loader.cpython-311.pyc
#    from /tmp/pip-uninstall-wxyocacd/python/util/__pycache__/lazy_loader.cpython-311.pyc
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/__pycache__/lock_util.cpython-311.pyc
#    from /tmp/pip-uninstall-wxyocacd/python/util/__pycache__/lock_util.cpython-311.pyc
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/__pycache__/module_wrapper.cpython-311.pyc
#    from /tmp/pip-uninstall-wxyocacd/python/util/__pycache__/module_wrapper.cpython-311.pyc
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/__pycache__/nest.cpython-311.pyc
#    from /tmp/pip-uninstall-wxyocacd/python/util/__pycache__/nest.cpython-311.pyc
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/__pycache__/nest_util.cpython-311.pyc
#    from /tmp/pip-uninstall-wxyocacd/python/util/__pycache__/nest_util.cpython-311.pyc
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/__pycache__/object_identity.cpython-311.pyc
#    from /tmp/pip-uninstall-wxyocacd/python/util/__pycache__/object_identity.cpython-311.pyc
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/__pycache__/serialization.cpython-311.pyc
#    from /tmp/pip-uninstall-wxyocacd/python/util/__pycache__/serialization.cpython-311.pyc
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/__pycache__/tf_contextlib.cpython-311.pyc
#    from /tmp/pip-uninstall-wxyocacd/python/util/__pycache__/tf_contextlib.cpython-311.pyc
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/__pycache__/tf_decorator.cpython-311.pyc
#    from /tmp/pip-uninstall-wxyocacd/python/util/__pycache__/tf_decorator.cpython-311.pyc
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/__pycache__/tf_export.cpython-311.pyc
#    from /tmp/pip-uninstall-wxyocacd/python/util/__pycache__/tf_export.cpython-311.pyc
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/__pycache__/tf_inspect.cpython-311.pyc
#    from /tmp/pip-uninstall-wxyocacd/python/util/__pycache__/tf_inspect.cpython-311.pyc
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/__pycache__/tf_should_use.cpython-311.pyc
#    from /tmp/pip-uninstall-wxyocacd/python/util/__pycache__/tf_should_use.cpython-311.pyc
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/__pycache__/tf_stack.cpython-311.pyc
#    from /tmp/pip-uninstall-wxyocacd/python/util/__pycache__/tf_stack.cpython-311.pyc
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/__pycache__/traceback_utils.cpython-311.pyc
#    from /tmp/pip-uninstall-wxyocacd/python/util/__pycache__/traceback_utils.cpython-311.pyc
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/__pycache__/type_annotations.cpython-311.pyc
#    from /tmp/pip-uninstall-wxyocacd/python/util/__pycache__/type_annotations.cpython-311.pyc
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/__pycache__/variable_utils.cpython-311.pyc
#    from /tmp/pip-uninstall-wxyocacd/python/util/__pycache__/variable_utils.cpython-311.pyc
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/_pywrap_checkpoint_reader.so
#    from /tmp/pip-uninstall-wxyocacd/python/util/_pywrap_checkpoint_reader.so
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/_pywrap_determinism.so
#    from /tmp/pip-uninstall-wxyocacd/python/util/_pywrap_determinism.so
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/_pywrap_kernel_registry.so
#    from /tmp/pip-uninstall-wxyocacd/python/util/_pywrap_kernel_registry.so
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/_pywrap_nest.so
#    from /tmp/pip-uninstall-wxyocacd/python/util/_pywrap_nest.so
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/_pywrap_stat_summarizer.so
#    from /tmp/pip-uninstall-wxyocacd/python/util/_pywrap_stat_summarizer.so
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/_pywrap_tensor_float_32_execution.so
#    from /tmp/pip-uninstall-wxyocacd/python/util/_pywrap_tensor_float_32_execution.so
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/_pywrap_tfprof.so
#    from /tmp/pip-uninstall-wxyocacd/python/util/_pywrap_tfprof.so
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/_pywrap_transform_graph.so
#    from /tmp/pip-uninstall-wxyocacd/python/util/_pywrap_transform_graph.so
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/_pywrap_util_port.so
#    from /tmp/pip-uninstall-wxyocacd/python/util/_pywrap_util_port.so
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/_pywrap_utils.so
#    from /tmp/pip-uninstall-wxyocacd/python/util/_pywrap_utils.so
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/_tf_stack.so
#    from /tmp/pip-uninstall-wxyocacd/python/util/_tf_stack.so
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/all_util.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/all_util.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/compat.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/compat.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/decorator_utils.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/decorator_utils.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/deprecated_module.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/deprecated_module.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/deprecated_module_new.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/deprecated_module_new.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/deprecation.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/deprecation.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/dispatch.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/dispatch.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/example_parser_configuration.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/example_parser_configuration.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/fast_module_type.so
#    from /tmp/pip-uninstall-wxyocacd/python/util/fast_module_type.so
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/function_utils.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/function_utils.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/is_in_graph_mode.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/is_in_graph_mode.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/keras_deps.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/keras_deps.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/keyword_args.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/keyword_args.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/lazy_loader.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/lazy_loader.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/lock_util.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/lock_util.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/module_wrapper.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/module_wrapper.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/nest.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/nest.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/nest_util.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/nest_util.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/object_identity.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/object_identity.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/protobuf/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/~rotobuf
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/serialization.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/serialization.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/tf_contextlib.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/tf_contextlib.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/tf_decorator.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/tf_decorator.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/tf_export.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/tf_export.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/tf_inspect.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/tf_inspect.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/tf_should_use.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/tf_should_use.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/tf_stack.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/tf_stack.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/traceback_utils.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/type_annotations.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/type_annotations.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/variable_utils.py
#    from /tmp/pip-uninstall-wxyocacd/python/util/variable_utils.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/security/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/~ecurity
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/tools/__init__.py
#    from /tmp/pip-uninstall-wxyocacd/tools/__init__.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/tools/__pycache__/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/tools/~_pycache__
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/tools/common/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/tools/~ommon
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/tools/compatibility/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/tools/~ompatibility
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/tools/docs/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/tools/~ocs
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/tools/pip_package/__init__.py
#    from /tmp/pip-uninstall-wxyocacd/tools/pip_package/__init__.py
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/tools/pip_package/__pycache__/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/tools/pip_package/~_pycache__
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/tsl/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/~sl
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/xla_aot_runtime_src/CMakeLists.txt
#    from /tmp/pip-uninstall-wxyocacd/xla_aot_runtime_src/CMakeLists.txt
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/xla_aot_runtime_src/tensorflow/compiler/tf2xla/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/xla_aot_runtime_src/tensorflow/compiler/~f2xla
#   Moving to /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/xla_aot_runtime_src/tensorflow/core/platform/
#    from /home/truongnguyen/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/xla_aot_runtime_src/tensorflow/core/~latform
# ERROR: Could not install packages due to an OSError: [Errno 28] No space left on device
#
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# 2024-04-11 21:37:58.588097: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-11 21:37:58.589504: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-11 21:37:58.665771: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-11 21:37:58.973005: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-11 21:38:00.274857: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# Lets load our training images for processing

# %%
batch_size = 32
img_height = 224
img_width = 224
data_root = 'dataset/taphuanluyen/glass'
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  str(data_root),
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[10], line 5
#       3 img_width = 224
#       4 data_root = 'dataset/taphuanluyen/glass'
# ----> 5 train_ds = tf.keras.preprocessing.image_dataset_from_directory(
#       6   str(data_root),
#       7   validation_split=0.2,
#       8   subset="training",
#       9   seed=123,
#      10   image_size=(img_height, img_width),
#      11   batch_size=batch_size)
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/keras/src/utils/image_dataset_utils.py:223, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, verbose)
#     221 if seed is None:
#     222     seed = np.random.randint(1e6)
# --> 223 image_paths, labels, class_names = dataset_utils.index_directory(
#     224     directory,
#     225     labels,
#     226     formats=ALLOWLIST_FORMATS,
#     227     class_names=class_names,
#     228     shuffle=shuffle,
#     229     seed=seed,
#     230     follow_links=follow_links,
#     231     verbose=verbose,
#     232 )
#     234 if label_mode == "binary" and len(class_names) != 2:
#     235     raise ValueError(
#     236         'When passing `label_mode="binary"`, there must be exactly 2 '
#     237         f"class_names. Received: class_names={class_names}"
#     238     )
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/keras/src/utils/dataset_utils.py:537, in index_directory(directory, labels, formats, class_names, shuffle, seed, follow_links, verbose)
#     535 if labels == "inferred":
#     536     subdirs = []
# --> 537     for subdir in sorted(tf.io.gfile.listdir(directory)):
#     538         if tf.io.gfile.isdir(tf.io.gfile.join(directory, subdir)):
#     539             if not subdir.startswith("."):
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/lib/io/file_io.py:768, in list_directory_v2(path)
#     753 """Returns a list of entries contained within a directory.
#     754
#     755 The list is in arbitrary order. It does not contain the special entries "."
#    (...)
#     765   errors.NotFoundError if directory doesn't exist
#     766 """
#     767 if not is_directory(path):
# --> 768   raise errors.NotFoundError(
#     769       node_def=None,
#     770       op=None,
#     771       message="Could not find directory {}".format(path))
#     773 # Convert each element to string, since the return values of the
#     774 # vector of string should be interpreted as strings, not bytes.
#     775 return [
#     776     compat.as_str_any(filename)
#     777     for filename in _pywrap_file_io.GetChildren(compat.path_to_bytes(path))
#     778 ]
#
# NotFoundError: Could not find directory dataset/taphuanluyen/glass

# %%
class_names = np.array(train_ds.class_names)
print('class names for predictions :',class_names)
# Out:
# class names for predictions : ['cardboard' 'glass' 'metal' 'paper' 'plastic' 'trash']

# %% [markdown]
# TensorFlow Hub's conventions for image models is to expect **float** inputs in the **[0, 1]** range. Use the **Rescaling layer** to achieve this.

# %%
normalization_layer = tf.keras.layers.Rescaling(1./255)
train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))

# %% [markdown]
# Let's make sure to use buffered prefetching so we can yield data from disk without having I/O become blocking. These are two important methods you should use when loading data.

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 224, 224, 3)
# (32,)
# 2024-04-11 21:04:39.318856: W tensorflow/core/kernels/data/cache_dataset_ops.cc:858] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %% [markdown]
# TensorFlow Hub also distributes models without the top classification layer. These can be used to easily do transfer learning.

# %%
feature_extractor_model = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"
feature_extractor_layer = hub.KerasLayer(
    feature_extractor_model, input_shape=(224, 224, 3), trainable=False)

# %%
num_classes = len(class_names)

model = tf_keras.Sequential([
  feature_extractor_layer,
  tf_keras.layers.Dense(num_classes, name = 'output')
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer_3 (KerasLayer)  (None, 1280)              2257984
#
#  output (Dense)              (None, 5)                 6405
#
# =================================================================
# Total params: 2264389 (8.64 MB)
# Trainable params: 6405 (25.02 KB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
image_batch.shape
# Out:
# TensorShape([32, 224, 224, 3])

# %% [markdown]
# # Train the model

# %%
model.compile(
  optimizer=tf_keras.optimizers.Adam(),
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['acc'])

# %% [markdown]
#  To visualize the training progress, use a custom callback to log the loss and accuracy of each batch individually, instead of the epoch average.

# %%
class CollectBatchStats(tf_keras.callbacks.Callback):
  def __init__(self):
    self.batch_losses = []
    self.batch_acc = []

  def on_train_batch_end(self, batch, logs=None):
    self.batch_losses.append(logs['loss'])
    self.batch_acc.append(logs['acc'])
    self.model.reset_metrics()

batch_stats_callback = CollectBatchStats()

history = model.fit(train_ds, epochs=5,
                    callbacks=[batch_stats_callback])
# Out:
# Epoch 1/5
# 355/355 [==============================] - 234s 572ms/step - loss: 0.0000e+00 - acc: 0.0000e+00
# Epoch 2/5
# 355/355 [==============================] - 205s 577ms/step - loss: 0.0000e+00 - acc: 0.0000e+00
# Epoch 3/5
# 355/355 [==============================] - 199s 560ms/step - loss: 0.0000e+00 - acc: 0.0000e+00
# Epoch 4/5
# 355/355 [==============================] - 196s 552ms/step - loss: 0.0000e+00 - acc: 0.0000e+00
# Epoch 5/5
# 207/355 [================>.............] - ETA: 1:04 - loss: 0.1193 - acc: 0.9688
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 13
#       9     self.model.reset_metrics()
#      11 batch_stats_callback = CollectBatchStats()
# ---> 13 history = model.fit(train_ds, epochs=5,
#      14                     callbacks=[batch_stats_callback])
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tf_keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tf_keras/src/engine/training.py:1804, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1796 with tf.profiler.experimental.Trace(
#    1797     "train",
#    1798     epoch_num=epoch,
#    (...)
#    1801     _r=1,
#    1802 ):
#    1803     callbacks.on_train_batch_begin(step)
# -> 1804     tmp_logs = self.train_function(iterator)
#    1805     if data_handler.should_sync:
#    1806         context.async_wait()
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:869, in Function._call(self, *args, **kwds)
#     866   self._lock.release()
#     867   # In this case we have created variables on the first call, so we run the
#     868   # defunned version which is guaranteed to never create variables.
# --> 869   return tracing_compilation.call_function(
#     870       args, kwds, self._no_variable_creation_config
#     871   )
#     872 elif self._variable_creation_config is not None:
#     873   # Release the lock early so that multiple threads can perform the call
#     874   # in parallel.
#     875   self._lock.release()
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# Now after, even just a few training iterations, we can already see that the model is making progress on the task.

# %%
plt.figure()
plt.ylabel("Loss")
plt.xlabel("Training Steps")
plt.ylim([0,2])
plt.plot(batch_stats_callback.batch_losses)

# %%
plt.figure()
plt.ylabel("Accuracy")
plt.xlabel("Training Steps")
plt.ylim([0,1])
plt.plot(batch_stats_callback.batch_acc)

# %% [markdown]
# To redo the plot from before, first get the ordered list of class names:

# %%
predicted_batch = model.predict(image_batch)
predicted_id = np.argmax(predicted_batch, axis=-1)
predicted_label_batch = class_names[predicted_id]

# %% [markdown]
# Plot the result

# %%
plt.figure(figsize=(10,9))
plt.subplots_adjust(hspace=0.5)
for n in range(30):
  plt.subplot(6,5,n+1)
  plt.imshow(image_batch[n])
  plt.title(predicted_label_batch[n].title())
  plt.axis('off')
_ = plt.suptitle("Model predictions")

# %% [markdown]
# ## Save the Model

# %%
t = time.time()

export_path = "saved_models/MobileNetV2"
model.save(export_path)

export_path
# Out:
# INFO:tensorflow:Assets written to: saved_models/MobileNetV2/assets
# INFO:tensorflow:Assets written to: saved_models/MobileNetV2/assets
# 'saved_models/MobileNetV2'
